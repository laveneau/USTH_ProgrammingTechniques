# %% [markdown]
# # Labwork 1 — Classes *(cleaned)*
#
# Exercises on Python classes. Each solution is written to a file with `%%writefile`, then run with `!python`.
# *(No `mypy` yet — typing is introduced in Labwork 2.)*

# %% [markdown]
# Run once to create the working directory.

# %%
import os, sys

# The interpreter that is running this notebook.
# On macOS there is often no `python` command at all, only `python3`, and adding a
# shell alias does not help: `!` cells run a NON-interactive shell that never reads
# your profile, and `%%script` launches the program directly, without any shell.
# `sys.executable` is an absolute path, so it keeps working after a `cd` too.
PY = sys.executable
os.makedirs('labwork1', exist_ok=True)
print('labwork1/ ready')
print(f'interpreter: {PY}')

# %% [markdown]
# ## Exercise 1
# Is the following piece of code correct? If not, modify it to obtain the expected behaviour
# (each dog should have **its own** list of tricks).

# %%
# %%writefile labwork1/exercise1.py
class Dog:

    tricks = []              # is this the right place for the list?

    def __init__(self, name):
        self.name = name

    def add_trick(self, trick):
        self.tricks.append(trick)


if __name__ == '__main__':
    d = Dog('Fido')
    d.add_trick('roll over')

    e = Dog('Buddy')
    e.add_trick('play dead')

    print(d.tricks)   # expected: ['roll over']

# %%
# !{PY} labwork1/exercise1.py

# %% [markdown]
# ## Exercise 2
# Define a class `Vegetable` with one instance variable: its `name` (e.g. `"Tomato"`, `"Lettuce"`).
# Build two objects and print their names.

# %%
# %%writefile labwork1/exercise2.py
# define a class named Vegetable

# then instantiate two objects,

# and print their name

# %%
# !{PY} labwork1/exercise2.py

# %% [markdown]
# ## Exercise 3
# Write a class to represent a vehicle:
# - it can transport a given number of people;
# - it can be engine-powered or not;
# - it has a maximum speed.
#
# Then write classes for bicycles, cars, boats and planes.

# %%
# %%writefile labwork1/exercise3.py
# write your solution here

# %%
# !{PY} labwork1/exercise3.py

# %% [markdown]
# ## Exercise 4
# Write a multiple-inheritance scheme:
# - `Vehicle` as above (with a small difference);
# - `Engine`: a combustion engine, with a method returning the fuel type as an `Enum`
#   (diesel, gasoline, kerosene, coal, electricity, solar...) and a method giving average consumption;
# - `Donkey` and `Bicycle`: vehicles without engine;
# - `Boat`, `Car`, `Airplane`: vehicles with engine.

# %%
# %%writefile labwork1/exercise4.py
from enum import Enum

# write your solution here

# %%
# !{PY} labwork1/exercise4.py

# %% [markdown]
# ## Exercise 5
# Write a `DoubleLinkedList` container with:
# - a constructor of an empty list,
# - an iterator (`__iter__`),
# - adding an element at the beginning,
# - removing the first element.
#
# Add a test program that: creates a list, adds ~10 elements, displays it in normal then reverse order,
# removes the first 5, displays it again, and verifies the removed elements are gone.

# %%
# %%writefile labwork1/exercise5.py
class DoubleLinkedList:
    pass


if __name__ == "__main__":
    # add your test here
    pass

# %%
# !{PY} labwork1/exercise5.py
